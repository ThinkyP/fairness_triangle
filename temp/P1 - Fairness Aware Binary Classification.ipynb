# %%
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.insert(1, '/home/ptr@itd.local/code/fairness_triangle/tools') # so i can import tools
from  gen_synth_data import *
from plot_helper import *

# %% [markdown]
# ### Plotting Fairness Aware Classifier with 11 different values of a

# %%
disc_factor = [0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi]
for df in disc_factor:
    X, Y, Y_sen = generate_synthetic_data(False, 1000, disc_factor=df)

    p_reg, f_reg = LogisticRegression(), LogisticRegression()
    p_reg.fit(X, Y)
    f_reg.fit(X, Y_sen)

    num_to_draw = 200 # we will only draw a small number of points to avoid clutter
    x_draw = X[:num_to_draw]
    y_draw = Y[:num_to_draw]
    Y_sen_draw = Y_sen[:num_to_draw]

    X_s_0 = x_draw[Y_sen_draw == 0.0]
    X_s_1 = x_draw[Y_sen_draw == 1.0]
    y_s_0 = y_draw[Y_sen_draw == 0.0]
    y_s_1 = y_draw[Y_sen_draw == 1.0]


    # Create a mesh grid of points
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

    # Predict probabilities for each point on the grid
    Y_pred_p = p_reg.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
    Y_pred_p = Y_pred_p.reshape(xx.shape)

    Y_pred_f = f_reg.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
    Y_pred_f = Y_pred_f.reshape(xx.shape)

    fig, axs = plt.subplots(3, 4, figsize=(18, 13))
    axs = axs.flatten()

    for i, a in enumerate(np.linspace(0, 1, 11)):
        Y_pred_all = a*Y_pred_p + (1-a)*Y_pred_f
        subplot_reg(axs[i], Y_pred_p,Y_pred_f, Y_pred_all, xx, yy, X_s_0, y_s_0, X_s_1, y_s_1, df, a,  legend_flag=True)
    plt.savefig(f"img/Synth_Data_Zafar{df:.2f}_norm_scale.png")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 32
#      29 Y_pred_f = f_reg.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
#      30 Y_pred_f = Y_pred_f.reshape(xx.shape)
# ---> 32 fig, axs = plt.subplots(3, 4, figsize=(18, 13))
#      33 axs = axs.flatten()
#      35 for i, a in enumerate(np.linspace(0, 1, 11)):
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1599, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1455 """
#    1456 Create a figure and a set of subplots.
#    1457
#    (...)
#    1596
#    1597 """
#    1598 fig = figure(**fig_kw)
# -> 1599 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1600                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1601                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1602                    width_ratios=width_ratios)
#    1603 return fig, axs
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:931, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     928     gridspec_kw['width_ratios'] = width_ratios
#     930 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 931 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     932                   subplot_kw=subplot_kw)
#     933 return axs
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/gridspec.py:298, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     296         subplot_kw["sharex"] = shared_with[sharex]
#     297         subplot_kw["sharey"] = shared_with[sharey]
# --> 298         axarr[row, col] = figure.add_subplot(
#     299             self[row, col], **subplot_kw)
#     301 # turn off redundant tick labeling
#     302 if sharex in ["col", "all"]:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:782, in FigureBase.add_subplot(self, *args, **kwargs)
#     780         args = tuple(map(int, str(args[0])))
#     781     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 782     ax = projection_class(self, *args, **pkw)
#     783     key = (projection_class, pkw)
#     784 return self._add_axes_internal(ax, key)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:651, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     649 self._sharey = sharey
#     650 self.set_label(label)
# --> 651 self.set_figure(fig)
#     652 # The subplotspec needs to be set after the figure (so that
#     653 # figure-level subplotpars are taken into account), but the figure
#     654 # needs to be set after self._position is initialized.
#     655 if subplotspec:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:829, in _AxesBase.set_figure(self, fig)
#     826 self.dataLim = mtransforms.Bbox.null()
#     827 self._viewLim = mtransforms.Bbox.unit()
#     828 self.transScale = mtransforms.TransformWrapper(
# --> 829     mtransforms.IdentityTransform())
#     831 self._set_lim_and_transforms()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/transforms.py:1770, in AffineBase.__init__(self, *args, **kwargs)
#    1769 def __init__(self, *args, **kwargs):
# -> 1770     super().__init__(*args, **kwargs)
#    1771     self._inverted = None
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/transforms.py:113, in TransformNode.__init__(self, shorthand_name)
#     107 pass_through = False
#     108 """
#     109 If pass_through is True, all ancestors will always be
#     110 invalidated, even if 'self' is already invalid.
#     111 """
# --> 113 def __init__(self, shorthand_name=None):
#     114     """
#     115     Parameters
#     116     ----------
#    (...)
#     120         ``str(transform)`` when DEBUG=True.
#     121     """
#     122     self._parents = {}
#
# KeyboardInterrupt:

# %% [markdown]
# ### Random Label Noise - 6 Views

# %%
np.random.seed(0)  # Set seed for reproducibility
flip_prob = 0.8  # Probability of flipping each value
disc_factor = [0]

for df in disc_factor:
    X, Y, Y_sen = generate_synthetic_data(False, 1000, disc_factor=df)
    
    #Here we corrupt the labels
    mask = np.random.rand(Y.shape[0]) < flip_prob
    Y_corrupted =  np.where(mask, -Y, Y)            # Y is -1 or 1
    Y_sen_corrupted = np.where(mask, 1 - Y_sen, Y_sen) #Y_sen is 0 or 1!!!

    p_reg, p_reg_cor, f_reg, f_reg_cor = LogisticRegression(), LogisticRegression(), LogisticRegression(), LogisticRegression()
    p_reg.fit(X, Y)
    p_reg_cor.fit(X, Y_corrupted)
    f_reg.fit(X, Y_sen)
    f_reg_cor.fit(X, Y_sen_corrupted)

    #We only draw a small number of points to avoid clutter in plot
    num_to_draw = 200
    x_draw = X[:num_to_draw]
    y_draw = Y[:num_to_draw]
    Y_sen_draw = Y_sen[:num_to_draw]

    X_s_0 = x_draw[Y_sen_draw == 0.0]
    X_s_1 = x_draw[Y_sen_draw == 1.0]
    y_s_0 = y_draw[Y_sen_draw == 0.0]
    y_s_1 = y_draw[Y_sen_draw == 1.0]

    # Create a mesh grid of points
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

    # Predict class probabilities Y=1|X for each point on the grid
    Y_pred_p = p_reg.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1].reshape(xx.shape)
    Y_pred_p_cor = p_reg_cor.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1].reshape(xx.shape)
    Y_pred_f = f_reg.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1].reshape(xx.shape)
    Y_pred_f_cor = f_reg_cor.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1].reshape(xx.shape)

    #Plotting
    fig, axs = plt.subplots(2, 3, figsize=(18, 13))
    axs = axs.flatten()

    for i, a in enumerate(np.linspace(0, 1, 6)):
        Y_pred_all = a*Y_pred_p_cor + (1-a)*Y_pred_f_cor
        subplot_reg_corr(fig, axs[i], Y_pred_p, Y_pred_p_cor, Y_pred_f,Y_pred_f_cor, Y_pred_all, xx, yy, X_s_0, y_s_0, X_s_1, y_s_1, disc_factor=df, a=a, legend_outside=True)
    plt.savefig(f"img/fairness_aware_regression_synthetic_data_rnd_label_noise_6/fairness_aware_regression_df_{df:.2f}_label_noise_{flip_prob}.png")

# %%
p_reg.predict_proba([[3,2]])
# Out:
# array([[0.04719502, 0.95280498]])

# %% [markdown]
# ### Sensitive Attribute Noise - 6 Views

# %%
np.random.seed(0)  # Set seed for reproducibility
flip_prob = 0.2  # Probability of flipping each value
disc_factor = [np.pi/4]

for df in disc_factor:
    X, Y, Y_sen = generate_synthetic_data(False, 1000, disc_factor=df)
    
    #Here we corrupt the labels
    mask = np.random.rand(Y.shape[0]) < flip_prob
    Y_corrupted =  Y           # Y is -1 or 1
    Y_sen_corrupted = np.where(mask, 1 - Y_sen, Y_sen) #Y_sen is 0 or 1!!!

    p_reg, p_reg_cor, f_reg, f_reg_cor = LogisticRegression(), LogisticRegression(), LogisticRegression(), LogisticRegression()
    p_reg.fit(X, Y)
    p_reg_cor.fit(X, Y_corrupted)
    f_reg.fit(X, Y_sen)
    f_reg_cor.fit(X, Y_sen_corrupted)

    #We only draw a small number of points to avoid clutter in plot
    num_to_draw = 200
    x_draw = X[:num_to_draw]
    y_draw = Y[:num_to_draw]
    Y_sen_draw = Y_sen[:num_to_draw]

    X_s_0 = x_draw[Y_sen_draw == 0.0]
    X_s_1 = x_draw[Y_sen_draw == 1.0]
    y_s_0 = y_draw[Y_sen_draw == 0.0]
    y_s_1 = y_draw[Y_sen_draw == 1.0]

    # Create a mesh grid of points
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

    # Predict probabilities for each point on the grid
    Y_pred_p = p_reg.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1].reshape(xx.shape)
    Y_pred_p_cor = p_reg_cor.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1].reshape(xx.shape)
    Y_pred_f = f_reg.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1].reshape(xx.shape)
    Y_pred_f_cor = f_reg_cor.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1].reshape(xx.shape)

    #Plotting
    fig, axs = plt.subplots(2, 3, figsize=(18, 13))
    axs = axs.flatten()

    for i, a in enumerate(np.linspace(0, 1, 6)):
        Y_pred_all = a*Y_pred_p_cor + (1-a)*Y_pred_f_cor
        subplot_reg_corr(fig, axs[i], Y_pred_p, Y_pred_p_cor, Y_pred_f,Y_pred_f_cor, Y_pred_all, xx, yy, X_s_0, y_s_0, X_s_1, y_s_1, disc_factor=df, a=a, legend_outside=True)
    plt.savefig(f"img/fairness_aware_regression_synthetic_data_sen_label_noise_6/fairness_aware_regression_df_{df:.2f}_label_noise_{flip_prob}.png")
