# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import glob

# Load images
image_files = sorted(glob.glob("/home/preuer/OneDrive/Studium/Master/Semester/Sem_4/Master Thesis/fairness_triangle/img/E1_Label_Noise_for_Single_Points/*.png"))  # Adjust path

# Create figure
fig, ax = plt.subplots()
ax.axis("off")  # Hide axis
img = plt.imshow(plt.imread(image_files[0]))  # Load first image

# Update function
def update(frame):
    img.set_array(plt.imread(image_files[frame]))
    return img,

# Create animation
ani = animation.FuncAnimation(fig, update, frames=len(image_files), interval=500, blit=True)

# Save as GIF (or use plt.show() to view it live)
ani.save("animated_plot.gif", writer=animation.PillowWriter(fps=2))

plt.show()
